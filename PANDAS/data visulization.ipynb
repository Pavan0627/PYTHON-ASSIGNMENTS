# %% [markdown]
# #### Exploratory Data Analysis (EDA) is an approach to analyze the data using visual techniques. It is used to discover trends, patterns, or to check assumptions with the help of statistical summary and graphical representations.
#
# Dataset Used
# For the simplicity of the article, we will use a single dataset. We will use the employee data for this. It contains 8 columns namely – First Name, Gender, Start Date, Last Login, Salary, Bonus%, Senior Management, and Team.

# %%
#for data manipulation
import numpy as np
import pandas as pd

#for data visualization
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## loading data

# %%
HQ=pd.read_csv('Happiness_Quotient_2019.csv')
HQ.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#dimension of data
HQ.shape
# Out:
# (157, 9)

# %%
HQ.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    157.000000  155.000000      157.000000      157.000000
# mean      78.993631    5.382484        0.901331        1.204777
# std       45.455176    1.132044        0.399979        0.302490
# min        1.000000    2.853000        0.000000        0.000000
# 25%       40.000000    4.526500        0.578000        1.055000
# 50%       79.000000    5.339000        0.960000        1.269000
# 75%      118.000000    6.178000        1.231000        1.452000
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               157.000000                    155.000000  157.000000
# mean                  0.722503                      0.389723    0.184955
# std                   0.243777                      0.146911    0.094959
# min                   0.000000                      0.000000    0.000000
# ...

# %%
HQ.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           2
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    2
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
HQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  157 non-null    int64
#  1   Country or region             157 non-null    object
#  2   Score                         155 non-null    float64
#  3   GDP per capita                157 non-null    float64
#  4   Social support                157 non-null    float64
#  5   Healthy life expectancy       157 non-null    float64
#  6   Freedom to make life choices  155 non-null    float64
#  7   Generosity                    157 non-null    float64
#  8   Perceptions of corruption     157 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.2+ KB

# %%
duplicate = HQ[HQ.duplicated()]
duplicate
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 156           156       South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 156                    0.295                          0.01       0.202
#
#      Perceptions of corruption
# 156                      0.091

# %%
HQ.drop_duplicates()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
HQ['Score'].fillna(5.382484, inplace=True)
HQ['Freedom to make life choices'].fillna(0.389723, inplace=True)

# %%
HQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  157 non-null    int64
#  1   Country or region             157 non-null    object
#  2   Score                         157 non-null    float64
#  3   GDP per capita                157 non-null    float64
#  4   Social support                157 non-null    float64
#  5   Healthy life expectancy       157 non-null    float64
#  6   Freedom to make life choices  157 non-null    float64
#  7   Generosity                    157 non-null    float64
#  8   Perceptions of corruption     157 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.2+ KB

# %%
HQ[HQ['Perceptions of corruption']==0]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 70            71           Moldova  5.529           0.685           1.328
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 70                    0.739                         0.245       0.181
#
#     Perceptions of corruption
# 70                        0.0

# %%
HQ['Perceptions of corruption'].min()
# Out:
# 0.0

# %%
HQ['Perceptions of corruption'].idxmax(axis=0)
# Out:
# 33

# %% [markdown]
# ### handling outliers

# %%
HQ.boxplot('Score','GDP per capita','Social support','Perceptions of corruption',
           'Healthy life expectancy','Freedom to make life choices','Generosity', figsize=(25,40))
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 HQ.boxplot('Score','GDP per capita','Social support','Perceptions of corruption','Healthy life expectancy','Freedom to make life choices','Generosity', figsize=(25,40))
#       2 plt.show
#
# TypeError: boxplot_frame() got multiple values for argument 'figsize'

# %%
# HQ.boxplot(column=['Perceptions of corruption'])
# plt.show

# %%
# HQ.boxplot(column=['Freedom to make life choices'])
# plt.show

# %%
upper_limit = df[‘fare_amount’].mean() + 3*df[‘fare_amount’].std()

print(upper_limit)

lower_limit = df[‘fare_amount’].mean() – 3*df[‘fare_amount’].std()

print(lower_limit)

# %%
df[‘fare_amount’] = np.where(df[‘fare_amount’] > upper_limit,

   upper_limit,

   np.where(

       df[‘fare_amount’] < lower_limit,

       lower_limit,

       df[‘fare_amount’]

   )

)

# %%
def impute_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   upper = df[~(df>(q3+1.5*IQR))].max()

   lower = df[~(df<(q1-1.5*IQR))].min()

   df = np.where(df > upper,

       df.mean(),

       np.where(

           df < lower,

           df.mean(),

           df

           )

       )

   return df
